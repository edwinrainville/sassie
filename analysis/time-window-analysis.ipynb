# %%
import cartopy
import cv2
import cmocean
import cftime
from datetime import datetime, timedelta
import numpy as np
import netCDF4 as nc
import pandas as pd
import pyproj as proj
import matplotlib.pyplot as plt
import matplotlib.colors
import matplotlib.dates as mdates
import metpy.calc as mpcalc
from scipy import io, interpolate, stats, signal
from scipy.optimize import curve_fit
from scipy.spatial import cKDTree

# %matplotlib widget

# %%
# Load all Data frames
df1 = pd.read_csv('../data/play1_window1_df.csv')
df2 = pd.read_csv('../data/play1_window2_df.csv')
df3 = pd.read_csv('../data/play1_window3_df.csv')
df4 = pd.read_csv('../data/play1_window4_df.csv')
df5 = pd.read_csv('../data/play1_window5_df.csv')
df6 = pd.read_csv('../data/play1_window6_df.csv')
df7 = pd.read_csv('../data/play1_window7_df.csv')

# %%
# Plot the Updated Significant Wave Height Normalized
fig, ax = plt.subplots()
ax.scatter(df1['cross ice distance'], df1['hs_norm'])
ax.scatter(df2['cross ice distance'], df2['hs_norm'])
ax.scatter(df3['cross ice distance'], df3['hs_norm'])
ax.scatter(df4['cross ice distance'], df4['hs_norm'])
ax.scatter(df5['cross ice distance'], df5['hs_norm'])
ax.scatter(df6['cross ice distance'], df6['hs_norm'])
ax.scatter(df7['cross ice distance'], df7['hs_norm'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(df1['alpha'][0])
print(df2['alpha'][0])
print(df3['alpha'][0])
print(df4['alpha'][0])
print(df5['alpha'][0])
print(df6['alpha'][0])
print(df7['alpha'][0])
# Out:
# 0.0026075668882562
# 0.0029
# 0.0029
# 3.734690086807143e-05
